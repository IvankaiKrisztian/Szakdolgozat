# %%
import polars as pl
from polars import *

# %%
df = pl.DataFrame([
    (0.5,0.5, 50),
    (1.0,0.0, 20),
    (0.0,1.0, 70),
    (0.3,0.7, 60),
    (0.9,0.1, 40),

],
    ['Young','Old','Age'],orient='row').with_columns(lit('1').alias('name'))

# %%
df
# Out:
# shape: (5, 4)
# ┌───────┬─────┬─────┬──────┐
# │ Young ┆ Old ┆ Age ┆ name │
# │ ---   ┆ --- ┆ --- ┆ ---  │
# │ f64   ┆ f64 ┆ i64 ┆ str  │
# ╞═══════╪═════╪═════╪══════╡
# │ 0.5   ┆ 0.5 ┆ 50  ┆ 1    │
# │ 1.0   ┆ 0.0 ┆ 20  ┆ 1    │
# │ 0.0   ┆ 1.0 ┆ 70  ┆ 1    │
# │ 0.3   ┆ 0.7 ┆ 60  ┆ 1    │
# │ 0.9   ┆ 0.1 ┆ 40  ┆ 1    │
# └───────┴─────┴─────┴──────┘

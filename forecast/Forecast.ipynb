# %%
import sys
sys.path.append("/Users/krisztianivankai/PycharmProjects/Szakdolgozat/")
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import timedelta
import holidays

from models.fuzzy import get_all_fuzzy_membership_values, create_fuzzified_lag_df, fuzzy_forecast_pipeline
from models.moving_average import forecast_moving_average
from utilities.utils import plot_average_by_group, get_split_date
from evaluate.evaluate_model import get_model_score
from forecast import forecast_over_horizon
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 13
#      11 from utilities.utils import plot_average_by_group, get_split_date
#      12 from evaluate.evaluate_model import get_model_score
# ---> 13 from forecast import forecast_over_horizon
#
# ImportError: cannot import name 'forecast_over_horizon' from 'forecast' (/Users/krisztianivankai/PycharmProjects/Szakdolgozat/forecast/__init__.py)

# %%
sales_and_stock = pd.read_csv('../data/Szakdoga_adat.csv')
split_percentage = 0.8

# %%
sales_and_stock

# %%
split_date = get_split_date(sales_and_stock['date'], split_percentage)
